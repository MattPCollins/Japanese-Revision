# %%
import pandas as pd
fact_streak = '/Users/mattcollins/Projects/MyProject/KanjiProgram/csvs/fact_streak.csv'
results = '/Users/mattcollins/Projects/MyProject/KanjiProgram/csvs/results2.csv'
dictionary = '/Users/mattcollins/Projects/MyProject/KanjiProgram/csvs/word_dictionary.csv'

# %%
df_fs = pd.read_csv(fact_streak)
df_d = pd.read_csv(dictionary)
df_d.rename(columns={'word index':'index_word'}, inplace=True)

# %%
# df_super = pd.merge(df_fs, df_d, on='index_word', how='outer')
# df_super
# Out:
#       index_word  streak        date  sample_x            english  hiragana  \
# 0              1       8  04/08/2020         1  (someone's) house       おたく
# 1              1       9  04/09/2020         1  (someone's) house       おたく
# 2              1      10  05/10/2020         1  (someone's) house       おたく
# 3              5       8  04/08/2020         1             karate       からて
# 4              5       9  04/09/2020         1             karate       からて
# ...          ...     ...         ...       ...                ...       ...
# 4448         573       0  02/01/2021         4     a kind; a sort      しゅるい
# 4449         574       0  02/01/2021         4        lazy person     なまけもの
# 4450         575       1  02/01/2021         4              worry       なやみ
# 4451         576       0  02/01/2021         4         shy person  はずかしいがりや
# 4452         577       0  02/01/2021         4            culture       ぶんか
#
#          kanji  date_added  rank  sample_y  is_active
# ...

# %%
pd.set_option('display.max_rows', None)
pd.pivot_table(df_super, index = ['index_word','date'], values = ['streak']).sort_values(['index_word', 'date'])
# pd.pivot_table(df_super, index = ['index_word'], values = ['streak'], aggfunc='count').sort_values(['index_word'])
# Out:
#       sample_x  sample_y
# 0            1         1
# 1            1         1
# 2            1         1
# 3            1         1
# 4            1         1
# 5            1         1
# 6            1         1
# 7            1         1
# 8            1         1
# 9            1         1
# 10           1         1
# 11           1         1
# 12           1         1
# 13           1         1
# 14           1         1
# 15           1         1
# 16           1         1
# 17           1         1
# 18           1         1
# 19           1         1
# 20           1         1
# 21           1         1
# 22           1         1
# 23           1         1
# 24           1         1
# 25           1         1
# 26           1         1
# 27           1         1
# 28           1         1
# 29           1         1
# 30           1         1
# 31           1         1
# 32           1         1
# 33           1         1
# 34           1         1
# 35           1         1
# ...

# %%
variation = df_super.groupby(['index_word'])['index_word'].count()
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_super.drop(['sample_y'], axis=1)
# Out:
#       index_word  streak        date  sample_x  \
# 0              1       8  04/08/2020         1
# 1              1       9  04/09/2020         1
# 2              1      10  05/10/2020         1
# 3              5       8  04/08/2020         1
# 4              5       9  04/09/2020         1
# 5              5      10  05/10/2020         1
# 6             16       8  04/08/2020         1
# 7             16       9  04/09/2020         1
# 8             16      10  05/10/2020         1
# 9             20       7  04/08/2020         1
# 10            20       8  04/09/2020         1
# 11            20       9  05/10/2020         1
# 12            20      10  05/11/2020         1
# 13            39       8  04/08/2020         1
# 14            39       9  04/09/2020         1
# 15            39      10  05/10/2020         1
# 16            41       5  04/08/2020         1
# 17            41       6  18/08/2020         1
# 18            41       7  01/09/2020         1
# ...

# %%
df_
